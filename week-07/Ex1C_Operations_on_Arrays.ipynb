# %% [markdown]
# # Exercise 1.C Performing operations on arrays

# %%
import numpy as np

# %% [markdown]
# # sample arrays

# %%
r_1 = np.random.randint(1, 21, size=2)
r_2 = np.random.randint(1, 21, size=(1, 2))
r_3 = np.random.rand(2, 1)
r_4 = np.random.randint(20, 101, size=(4, 5))
r_5 = np.random.rand(4, 5)

print(r_1)
print(r_2)
print(r_3)
print(r_4)
print(r_5)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[29], line 7
#       4 r_4 = np.random.randint(20, 101, size=(4, 5))
#       5 r_5 = np.random.rand(4, 5)
# ----> 7 print(r_1)
#       8 print(r_2)
#       9 print(r_3)
#
# TypeError: 'tuple' object is not callable

# %% [markdown]
# # permutations

# %%
print(r_4)
# Out:
# [[34 73 21 21 74]
#  [51 55 39 56 71]
#  [72 65 36 25 77]
#  [56 54 43 52 55]]

# %%
np.random.shuffle(r_4)
print(r_4)
# Out:
# [[56 54 43 52 55]
#  [34 73 21 21 74]
#  [72 65 36 25 77]
#  [51 55 39 56 71]]

# %%
np.random.shuffle(r_4)
print(r_4)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[26], line 2
#       1 np.random.shuffle(r_4)
# ----> 2 print(r_4)
#
# TypeError: 'tuple' object is not callable

# %%
#The shuffle function rearranges the rows of the array.
#It does not mix every number individually only the order of rows changes

# %%
new_shuffle = np.random.permutation(r_4)
print(new_shuffle)
print()
print(r_4)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[25], line 2
#       1 new_shuffle = np.random.permutation(r_4)
# ----> 2 print(new_shuffle)
#       3 print()
#       4 print(r_4)
#
# TypeError: 'tuple' object is not callable

# %%
# when you want to shuffle the info but not change the original input

# %% [markdown]
# ## Mathematical Operations.

# %%
print(r_1)
print(r_2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 print(r_1)
#       2 print(r_2)
#
# TypeError: 'tuple' object is not callable

# %%
print(r_1, r_1.shape)
print(r_3, r_3.shape)

result = np.add(r_1, r_3)
print(result)
print(result.shape)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 print(r_1, r_1.shape)
#       2 print(r_3, r_3.shape)
#       4 result = np.add(r_1, r_3)
#
# TypeError: 'tuple' object is not callable
